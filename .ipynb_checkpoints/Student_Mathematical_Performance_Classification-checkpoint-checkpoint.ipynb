# %% [markdown]
# # 🎓 Student Mathematical Performance Classification using SVM
# This notebook trains an SVM classifier to predict students' **Performance Level** using survey responses.
# Dataset location:
# `C:\Users\achar\AppData\Local\Programs\Python\Python311\Scripts\SVM\ASSETS\datasetmaths.xlsx`

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder, label_binarize
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, confusion_matrix, classification_report,
    roc_auc_score, RocCurveDisplay
)
import joblib
sns.set(style="whitegrid")

# %% [markdown]
# ### 2️⃣ 📊 Load and Inspect the Dataset
# We load the dataset from the specified Excel file and display its shape and the first few rows to understand its structure.

# %%
# Change path if needed
dataset_path = r"C:\Users\achar\AppData\Local\Programs\Python\Python311\Scripts\SVM\ASSETS\rebuilt_math_dataset.xlsx"

# sanity check
if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"Dataset not found at {dataset_path}. Please verify the path.")

df = pd.read_excel(dataset_path)
print("Dataset shape:", df.shape)
display(df.head())
# Out:
# Dataset shape: (300, 15)
#   How confident are you in solving mathematical problems without help?  \
# 0                                               Poor
# 1                                          Excellent
# 2                                            Average
# 3                                          Very Poor
# 4                                               Good
#
#   How well do you understand basic mathematical concepts (fractions, algebra, geometry, etc.)?  \
# 0                                            Average
# 1                                               Good
# 2                                               Good
# 3                                          Very Poor
# 4                                               Poor
#
#   How regularly do you practice math problems apart from school homework?  \
# 0                                               Good
# 1                                          Excellent
# 2                                            Average
# 3                                          Very Poor
# 4                                               Good
#
#   How easily can you apply formulas during exams or problem-solving?  \
# 0                                               Good
# 1                                               Good
# 2                                            Average
# 3                                               Poor
# 4                                            Average
#
#   How well do you understand word problems (application-based questions)?  \
# 0                                               Good
# 1                                          Excellent
# 2                                               Good
# 3                                          Very Poor
# 4                                            Average
#
#   How actively do you ask doubts or questions during math class?  \
# 0                                               Good
# 1                                               Good
# 2                                            Average
# 3                                          Very Poor
# 4                                            Average
#
#   How accurate are you in your mathematical calculations during exams or assignments?  \
# 0                                               Good
# 1                                          Excellent
# 2                                          Very Poor
# 3                                          Very Poor
# 4                                               Good
#
#   How comfortable are you with logical reasoning and analytical thinking questions?  \
# 0                                            Average
# 1                                          Excellent
# 2                                               Good
# 3                                               Poor
# 4                                               Good
#
#   How well do you remember mathematical formulas and theorems?  \
# 0                                          Excellent
# 1                                          Excellent
# 2                                          Very Poor
# 3                                          Very Poor
# 4                                               Good
#
#   How consistently do you score well in Mathematics exams?  \
# 0                                            Average
# 1                                          Excellent
# 2                                               Poor
# 3                                               Poor
# 4                                            Average
#
#   How much do you enjoy solving puzzles, riddles, or logic-based problems?  \
# 0                                            Average
# 1                                          Excellent
# 2                                               Good
# 3                                          Very Poor
# 4                                               Good
#
#   How much time do you dedicate to studying Mathematics daily?  \
# 0                                            Average
# 1                                               Good
# 2                                            Average
# 3                                               Poor
# 4                                               Good
#
#   How regularly do you revise previous math lessons before exams?  \
# 0                                          Excellent
# 1                                          Excellent
# 2                                            Average
# 3                                               Poor
# 4                                            Average
#
#   How confident are you in explaining a math concept to your classmates?  \
# 0                                               Good
# 1                                               Good
# 2                                            Average
# 3                                          Very Poor
# 4                                               Good
#
#    Performance Level
# 0                  4
# 1                  5
# 2                  3
# 3                  1
# 4                  4

# %%
# Show basic info
display(df.info())
display(df.describe(include='all').T)

# Show counts of Performance Level if present
if 'Performance Level' in df.columns:
    print("\nPerformance Level value counts:")
    display(df['Performance Level'].value_counts())
else:
    print("\nNo 'Performance Level' column found - please add it then re-run.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 15 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   How confident are you in solving mathematical problems without help?                          300 non-null    object
#  1   How well do you understand basic mathematical concepts (fractions, algebra, geometry, etc.)?  300 non-null    object
#  2   How regularly do you practice math problems apart from school homework?                       300 non-null    object
#  3   How easily can you apply formulas during exams or problem-solving?                            300 non-null    object
#  4   How well do you understand word problems (application-based questions)?                       300 non-null    object
#  5   How actively do you ask doubts or questions during math class?                                300 non-null    object
#  6   How accurate are you in your mathematical calculations during exams or assignments?           300 non-null    object
#  7   How comfortable are you with logical reasoning and analytical thinking questions?             300 non-null    object
#  8   How well do you remember mathematical formulas and theorems?                                  300 non-null    object
#  9   How consistently do you score well in Mathematics exams?                                      300 non-null    object
#  10  How much do you enjoy solving puzzles, riddles, or logic-based problems?                      300 non-null    object
#  11  How much time do you dedicate to studying Mathematics daily?                                  300 non-null    object
#  12  How regularly do you revise previous math lessons before exams?                               300 non-null    object
#  13  How confident are you in explaining a math concept to your classmates?                        300 non-null    object
#  14  Performance Level                                                                             300 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 35.3+ KB
# None
#                                                     count unique      top  \
# How confident are you in solving mathematical p...    300      5     Good
# How well do you understand basic mathematical c...    300      5  Average
# How regularly do you practice math problems apa...    300      5     Good
# How easily can you apply formulas during exams ...    300      5  Average
# How well do you understand word problems (appli...    300      5  Average
# How actively do you ask doubts or questions dur...    300      5     Good
# How accurate are you in your mathematical calcu...    300      5  Average
# How comfortable are you with logical reasoning ...    300      5  Average
# How well do you remember mathematical formulas ...    300      5  Average
# How consistently do you score well in Mathemati...    300      5     Good
# How much do you enjoy solving puzzles, riddles,...    300      5     Poor
# How much time do you dedicate to studying Mathe...    300      5     Good
# How regularly do you revise previous math lesso...    300      5  Average
# How confident are you in explaining a math conc...    300      5     Good
# Performance Level                                   300.0    NaN      NaN
#
#                                                    freq mean       std  min  \
# How confident are you in solving mathematical p...   74  NaN       NaN  NaN
# How well do you understand basic mathematical c...   79  NaN       NaN  NaN
# How regularly do you practice math problems apa...   75  NaN       NaN  NaN
# How easily can you apply formulas during exams ...   71  NaN       NaN  NaN
# How well do you understand word problems (appli...   79  NaN       NaN  NaN
# How actively do you ask doubts or questions dur...   84  NaN       NaN  NaN
# How accurate are you in your mathematical calcu...   72  NaN       NaN  NaN
# How comfortable are you with logical reasoning ...   68  NaN       NaN  NaN
# How well do you remember mathematical formulas ...   71  NaN       NaN  NaN
# How consistently do you score well in Mathemati...   79  NaN       NaN  NaN
# How much do you enjoy solving puzzles, riddles,...   66  NaN       NaN  NaN
# How much time do you dedicate to studying Mathe...   77  NaN       NaN  NaN
# How regularly do you revise previous math lesso...   68  NaN       NaN  NaN
# How confident are you in explaining a math conc...   70  NaN       NaN  NaN
# Performance Level                                   NaN  3.0  1.416576  1.0
#
#                                                     25%  50%  75%  max
# How confident are you in solving mathematical p...  NaN  NaN  NaN  NaN
# How well do you understand basic mathematical c...  NaN  NaN  NaN  NaN
# How regularly do you practice math problems apa...  NaN  NaN  NaN  NaN
# How easily can you apply formulas during exams ...  NaN  NaN  NaN  NaN
# How well do you understand word problems (appli...  NaN  NaN  NaN  NaN
# How actively do you ask doubts or questions dur...  NaN  NaN  NaN  NaN
# How accurate are you in your mathematical calcu...  NaN  NaN  NaN  NaN
# How comfortable are you with logical reasoning ...  NaN  NaN  NaN  NaN
# How well do you remember mathematical formulas ...  NaN  NaN  NaN  NaN
# How consistently do you score well in Mathemati...  NaN  NaN  NaN  NaN
# How much do you enjoy solving puzzles, riddles,...  NaN  NaN  NaN  NaN
# How much time do you dedicate to studying Mathe...  NaN  NaN  NaN  NaN
# How regularly do you revise previous math lesso...  NaN  NaN  NaN  NaN
# How confident are you in explaining a math conc...  NaN  NaN  NaN  NaN
# Performance Level                                   2.0  3.0  4.0  5.0
# Performance Level value counts:
# Performance Level
# 4    60
# 5    60
# 3    60
# 1    60
# 2    60
# Name: count, dtype: int64

# %%
# Mapping for Likert responses
likert_map = {
    "Very Poor": 1,
    "Poor": 2,
    "Average": 3,
    "Good": 4,
    "Excellent": 5
}

# Create a copy so we don't overwrite original unexpectedly
data = df.copy()

# Apply mapping to all object dtype columns except target
target_col = "Performance Level"

for col in data.columns:
    if col == target_col:
        continue
    if data[col].dtype == object:
        # replace known strings, keep other strings (like numeric-as-strings) handled by to_numeric
        data[col] = data[col].replace(likert_map)

# Try casting numeric columns
for col in data.columns:
    if data[col].dtype == object:
        # attempt to convert to numeric if they are numeric-like strings
        data[col] = pd.to_numeric(data[col], errors='ignore')

print("After mapping — sample:")
display(data.head())
# Out:
# After mapping — sample:
# C:\Users\achar\AppData\Local\Temp\ipykernel_40240\2328036943.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[col] = data[col].replace(likert_map)
#    How confident are you in solving mathematical problems without help?  \
# 0                                                  2
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  4
#
#    How well do you understand basic mathematical concepts (fractions, algebra, geometry, etc.)?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  1
# 4                                                  2
#
#    How regularly do you practice math problems apart from school homework?  \
# 0                                                  4
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  4
#
#    How easily can you apply formulas during exams or problem-solving?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    How well do you understand word problems (application-based questions)?  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  1
# 4                                                  3
#
#    How actively do you ask doubts or questions during math class?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  1
# 4                                                  3
#
#    How accurate are you in your mathematical calculations during exams or assignments?  \
# 0                                                  4
# 1                                                  5
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    How comfortable are you with logical reasoning and analytical thinking questions?  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  2
# 4                                                  4
#
#    How well do you remember mathematical formulas and theorems?  \
# 0                                                  5
# 1                                                  5
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    How consistently do you score well in Mathematics exams?  \
# 0                                                  3
# 1                                                  5
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    How much do you enjoy solving puzzles, riddles, or logic-based problems?  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  1
# 4                                                  4
#
#    How much time do you dedicate to studying Mathematics daily?  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  2
# 4                                                  4
#
#    How regularly do you revise previous math lessons before exams?  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    How confident are you in explaining a math concept to your classmates?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  1
# 4                                                  4
#
#    Performance Level
# 0                  4
# 1                  5
# 2                  3
# 3                  1
# 4                  4

# %%
# If target is textual (Low/Medium/High), encode them; if numeric already, keep as-is
if target_col not in data.columns:
    raise KeyError(f"Target column '{target_col}' not found. Add it and re-run.")

# If target is string labels like Low/Medium/High, encode
if data[target_col].dtype == object:
    le = LabelEncoder()
    data[target_col] = le.fit_transform(data[target_col])
    print("Encoded target classes:", dict(enumerate(le.classes_)))
else:
    # If numeric but possibly floats, round/convert to int
    if pd.api.types.is_float_dtype(data[target_col].dtype):
        # if your target is already a score (1-5) or categories (1/2/3) use as is
        data[target_col] = data[target_col].round().astype(int)

# Check for missing values and fill numeric columns with mean
if data.isna().sum().sum() > 0:
    print("Missing values found — imputing numeric columns with mean")
    numeric_cols = data.select_dtypes(include=[np.number]).columns
    data[numeric_cols] = data[numeric_cols].fillna(data[numeric_cols].mean())

display(data.head())
print("\nTarget value counts:")
display(data[target_col].value_counts())
# Out:
#    How confident are you in solving mathematical problems without help?  \
# 0                                                  2
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  4
#
#    How well do you understand basic mathematical concepts (fractions, algebra, geometry, etc.)?  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  1
# 4                                                  2
#
#    How regularly do you practice math problems apart from school homework?  \
# 0                                                  4
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  4
#
#    How easily can you apply formulas during exams or problem-solving?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    How well do you understand word problems (application-based questions)?  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  1
# 4                                                  3
#
#    How actively do you ask doubts or questions during math class?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  1
# 4                                                  3
#
#    How accurate are you in your mathematical calculations during exams or assignments?  \
# 0                                                  4
# 1                                                  5
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    How comfortable are you with logical reasoning and analytical thinking questions?  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  2
# 4                                                  4
#
#    How well do you remember mathematical formulas and theorems?  \
# 0                                                  5
# 1                                                  5
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    How consistently do you score well in Mathematics exams?  \
# 0                                                  3
# 1                                                  5
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    How much do you enjoy solving puzzles, riddles, or logic-based problems?  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  1
# 4                                                  4
#
#    How much time do you dedicate to studying Mathematics daily?  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  2
# 4                                                  4
#
#    How regularly do you revise previous math lessons before exams?  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    How confident are you in explaining a math concept to your classmates?  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  1
# 4                                                  4
#
#    Performance Level
# 0                  4
# 1                  5
# 2                  3
# 3                  1
# 4                  4
# Target value counts:
# Performance Level
# 4    60
# 5    60
# 3    60
# 1    60
# 2    60
# Name: count, dtype: int64

# %%
# Drop columns that are not features if any (like student ids) - attempt to auto-detect common names
exclude = [target_col]
# If columns such as "Timestamp" or "Email" exist, drop them too
for typical in ['Timestamp', 'Email', 'Name', 'StudentID', 'ID']:
    if typical in data.columns:
        exclude.append(typical)

X = data.drop(columns=exclude)
y = data[target_col]

print("Features shape:", X.shape)
print("Target shape:", y.shape)
display(X.columns)
# Out:
# Features shape: (300, 14)
# Target shape: (300,)
# Index(['How confident are you in solving mathematical problems without help?',
#        'How well do you understand basic mathematical concepts (fractions, algebra, geometry, etc.)?',
#        'How regularly do you practice math problems apart from school homework?',
#        'How easily can you apply formulas during exams or problem-solving?',
#        'How well do you understand word problems (application-based questions)?',
#        'How actively do you ask doubts or questions during math class?',
#        'How accurate are you in your mathematical calculations during exams or assignments?',
#        'How comfortable are you with logical reasoning and analytical thinking questions?',
#        'How well do you remember mathematical formulas and theorems?',
#        'How consistently do you score well in Mathematics exams?',
#        'How much do you enjoy solving puzzles, riddles, or logic-based problems?',
#        'How much time do you dedicate to studying Mathematics daily?',
#        'How regularly do you revise previous math lessons before exams?',
#        'How confident are you in explaining a math concept to your classmates?'],
#       dtype='object')

# %%
# Use stratify to keep class distribution
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)
print("Train shape:", X_train.shape, "Test shape:", X_test.shape)
# Out:
# Train shape: (210, 14) Test shape: (90, 14)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Optionally, put back into DataFrame for readability
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X.columns, index=X_train.index)
X_test_scaled_df  = pd.DataFrame(X_test_scaled, columns=X.columns, index=X_test.index)

# %%
# Baseline SVM (RBF)
svm_rbf = SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=42)
svm_rbf.fit(X_train_scaled, y_train)

y_pred = svm_rbf.predict(X_test_scaled)

acc = accuracy_score(y_test, y_pred)
print(f"Baseline SVM (RBF) Accuracy: {acc*100:.2f}%")
print("\nClassification report:")
print(classification_report(y_test, y_pred))
# Out:
# Baseline SVM (RBF) Accuracy: 86.67%
#
# Classification report:
#               precision    recall  f1-score   support
#
#            1       0.86      1.00      0.92        18
#            2       0.88      0.83      0.86        18
#            3       1.00      0.89      0.94        18
#            4       0.82      0.78      0.80        18
#            5       0.79      0.83      0.81        18
#
#     accuracy                           0.87        90
#    macro avg       0.87      0.87      0.87        90
# weighted avg       0.87      0.87      0.87        90

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - SVM (RBF)")
plt.show()

# %%
svm_lin = SVC(kernel='linear', C=1.0, probability=True, random_state=42)
svm_lin.fit(X_train_scaled, y_train)
y_pred_lin = svm_lin.predict(X_test_scaled)

acc_lin = accuracy_score(y_test, y_pred_lin)
print(f"Linear SVM Accuracy: {acc_lin*100:.2f}%")
print(classification_report(y_test, y_pred_lin))
# Out:
# Linear SVM Accuracy: 83.33%
#               precision    recall  f1-score   support
#
#            1       0.84      0.89      0.86        18
#            2       0.71      0.83      0.77        18
#            3       1.00      0.78      0.88        18
#            4       0.88      0.78      0.82        18
#            5       0.80      0.89      0.84        18
#
#     accuracy                           0.83        90
#    macro avg       0.85      0.83      0.83        90
# weighted avg       0.85      0.83      0.83        90

# %%
# Tune RBF kernel parameters C and gamma
param_grid = {
    'C': [0.1, 1, 10, 50],
    'gamma': ['scale', 0.01, 0.1, 1],
    'kernel': ['rbf']
}

grid = GridSearchCV(SVC(probability=True, random_state=42), param_grid, cv=5, n_jobs=-1, scoring='accuracy')
grid.fit(X_train_scaled, y_train)

print("Best params:", grid.best_params_)
best_svm = grid.best_estimator_

# Evaluate best model
y_pred_best = best_svm.predict(X_test_scaled)
print(f"Tuned SVM Accuracy: {accuracy_score(y_test, y_pred_best)*100:.2f}%")
print(classification_report(y_test, y_pred_best))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       1 # Tune RBF kernel parameters C and gamma
#       2 param_grid = {
#       3     'C': [0.1, 1, 10, 50],
#       4     'gamma': ['scale', 0.01, 0.1, 1],
#       5     'kernel': ['rbf']
#       6 }
# ----> 8 grid = GridSearchCV(SVC(probability=True, random_state=42), param_grid, cv=5, n_jobs=-1, scoring='accuracy')
#       9 grid.fit(X_train_scaled, y_train)
#      11 print("Best params:", grid.best_params_)
#
# NameError: name 'GridSearchCV' is not defined

# %%
# ROC-AUC for multiclass via one-vs-rest (requires binarized y)
classes = np.unique(y)
y_test_bin = label_binarize(y_test, classes=classes)
y_score = best_svm.predict_proba(X_test_scaled)

# Compute macro AUC
try:
    auc = roc_auc_score(y_test_bin, y_score, average='macro', multi_class='ovr')
    print(f"ROC-AUC (macro, OVR): {auc:.4f}")
except Exception as e:
    print("ROC-AUC computation error:", e)

# Plot ROC curves for each class
plt.figure(figsize=(8,6))
for i, cls in enumerate(classes):
    RocCurveDisplay.from_predictions(y_test_bin[:, i], y_score[:, i], name=f"Class {cls}", ax=plt.gca())
plt.title("ROC Curves (One-vs-Rest)")
plt.show()
# Out:
# ROC-AUC (macro, OVR): 0.9886

# %%
# RandomForest to approximate feature importances (not SVM direct)
rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train_scaled, y_train)
feat_imp = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)
display(feat_imp)

plt.figure(figsize=(10,6))
sns.barplot(x=feat_imp.values, y=feat_imp.index, palette="viridis")
plt.title("Approximate Feature Importances (RandomForest)")
plt.xlabel("Importance")
plt.show()
# Out:
# How actively do you ask doubts or questions during math class?                                  0.103674
# How accurate are you in your mathematical calculations during exams or assignments?             0.102385
# How confident are you in explaining a math concept to your classmates?                          0.101814
# How regularly do you practice math problems apart from school homework?                         0.090258
# How well do you remember mathematical formulas and theorems?                                    0.083458
# How much do you enjoy solving puzzles, riddles, or logic-based problems?                        0.064812
# How confident are you in solving mathematical problems without help?                            0.063428
# How well do you understand basic mathematical concepts (fractions, algebra, geometry, etc.)?    0.063122
# How comfortable are you with logical reasoning and analytical thinking questions?               0.061543
# How consistently do you score well in Mathematics exams?                                        0.056769
# How regularly do you revise previous math lessons before exams?                                 0.056320
# How well do you understand word problems (application-based questions)?                         0.054287
# How easily can you apply formulas during exams or problem-solving?                              0.054284
# How much time do you dedicate to studying Mathematics daily?                                    0.043846
# dtype: float64
# C:\Users\achar\AppData\Local\Temp\ipykernel_40240\1667034099.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feat_imp.values, y=feat_imp.index, palette="viridis")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import ConfusionMatrixDisplay
sns.set(style="whitegrid", font_scale=1.2)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_best)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(7,6))
sns.heatmap(cm_normalized, annot=True, cmap='coolwarm', fmt='.2f', 
            xticklabels=np.unique(y), yticklabels=np.unique(y))
plt.title("🔢 Normalized Confusion Matrix — SVM Classifier", fontsize=14)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# C:\Users\achar\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128290 (\N{INPUT SYMBOL FOR NUMBERS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Calculate class-wise accuracy
class_acc = cm.diagonal() / cm.sum(axis=1)

plt.figure(figsize=(7,5))
sns.barplot(x=np.unique(y), y=class_acc, palette="crest")
plt.title("🎯 Accuracy by Performance Level")
plt.xlabel("Performance Level")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
for i, v in enumerate(class_acc):
    plt.text(i, v + 0.02, f"{v*100:.1f}%", ha='center', fontsize=11)
plt.show()
# Out:
# C:\Users\achar\AppData\Local\Temp\ipykernel_40240\2063300967.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=np.unique(y), y=class_acc, palette="crest")
# C:\Users\achar\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import RocCurveDisplay

classes = np.unique(y)
y_test_bin = label_binarize(y_test, classes=classes)
y_score = best_svm.predict_proba(X_test_scaled)

plt.figure(figsize=(8,6))
for i, cls in enumerate(classes):
    RocCurveDisplay.from_predictions(y_test_bin[:, i], y_score[:, i],
                                     name=f"Class {cls}", ax=plt.gca())
plt.title("📈 ROC Curves — One-vs-Rest (SVM)", fontsize=14)
plt.show()
# Out:
# C:\Users\achar\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train_scaled, y_train)

feat_importances = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=feat_importances.values[:10], y=feat_importances.index[:10], palette="viridis")
plt.title("🔥 Top 10 Influential Features (Approximation)", fontsize=14)
plt.xlabel("Importance Score")
plt.ylabel("Question / Feature")
plt.show()
# Out:
# C:\Users\achar\AppData\Local\Temp\ipykernel_40240\362133213.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feat_importances.values[:10], y=feat_importances.index[:10], palette="viridis")
# C:\Users\achar\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128293 (\N{FIRE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn import metrics  # add this line if not already there

print("🎯 FINAL MODEL SUMMARY")
print("----------------------")
print(f"Best Parameters: {grid.best_params_}")
print(f"Overall Accuracy: {accuracy_score(y_test, y_pred_best)*100:.2f}%")
print(f"Macro F1-Score: {metrics.f1_score(y_test, y_pred_best, average='macro'):.3f}")
print(f"ROC-AUC (macro): {roc_auc_score(label_binarize(y_test, classes=np.unique(y)), y_score, average='macro'):.3f}")

plt.figure(figsize=(6,4))
sns.heatmap([[accuracy_score(y_test, y_pred_best)*100]], annot=True, fmt=".2f", cmap="YlGnBu")
plt.title("📊 Overall Model Accuracy (%)", fontsize=14)
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 🎯 FINAL MODEL SUMMARY
# ----------------------
# Best Parameters: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# Overall Accuracy: 88.89%
# Macro F1-Score: 0.888
# ROC-AUC (macro): 0.989
# C:\Users\achar\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import joblib
import os

# Define save directory (change path as needed)
save_dir = r"C:\Users\achar\AppData\Local\Programs\Python\Python311\Scripts\SVM\ASSETS"
os.makedirs(save_dir, exist_ok=True)

# Save model and scaler
model_path = os.path.join(save_dir, "svm_best_model.joblib")
scaler_path = os.path.join(save_dir, "scaler.joblib")

joblib.dump(best_svm, model_path)
joblib.dump(scaler, scaler_path)

print(f"✅ Model saved to: {model_path}")
print(f"✅ Scaler saved to: {scaler_path}")
# Out:
# ✅ Model saved to: C:\Users\achar\AppData\Local\Programs\Python\Python311\Scripts\SVM\ASSETS\svm_best_model.joblib
# ✅ Scaler saved to: C:\Users\achar\AppData\Local\Programs\Python\Python311\Scripts\SVM\ASSETS\scaler.joblib
